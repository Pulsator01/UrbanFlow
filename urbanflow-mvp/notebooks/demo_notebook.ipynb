# %% [markdown]
# # UrbanFlow Demo Notebook
#
# This notebook demonstrates the UrbanFlow MVP pipeline on a small GTFS feed.
#
# Use the CLI for end-to-end runs:
#
# ```bash
# urbanflow validate --gtfs path/to/feed.zip --out ./output/validation_report.json
# urbanflow run --gtfs path/to/feed.zip --constraints constraints.json --objective objective.json --outdir ./output
# ```
